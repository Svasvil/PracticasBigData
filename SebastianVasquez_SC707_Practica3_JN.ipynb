# %% [markdown]
# <a href="https://colab.research.google.com/github/Svasvil/PracticasBigData/blob/Practica3/SebastianVasquez_SC707_Practica3_JN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica 03 (5%) Entrega Semana 6, 17:30 horas

# %% [markdown]
# #### Cargue el archivo nhanes_2015_2016.csv en un dataFrame y realice las siguientes exploraciones:

# %% [markdown]
# 1. Usando la variable de estado civil [DMDMARTL](https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/2015/DataFiles/DEMO_I.htm#DMDMARTL) agregue una nueva columna al dataFrame llamada "EstadoCivil" con los valores descriptivos para que tenga etiquetas informativas.
# 1. Usando la variable RIAGENDR agregue una nueva columna al dataFrame llamada "Genero"con los valores descriptivos "Male" y "Female" (como lo hicimos en clases).
# 1. Restringiendo la muestra a la población femenina, estratifique a los sujetos en franjas de edad de diez años y construya la distribución del estado civil dentro de cada franja de edad. Presente la distribución en términos de proporciones que deben sumar 1. (Como lo hicimos al final de la clase al comparar grupos de edad con el nivel de educación).
# 1. Hacer lo mismo para la población masculina.
# 1. Construir histogramas separados para las alturas de mujeres y hombres usando la variable BMXHT
# 1. Construir un diagrama de caja (box plot) que muestre las alturas de mujeres y hombres.

# %% [markdown]
# #### Cargue el archivo starbucks_drinkMenu_expanded.csv en un dataFrame y realice las siguientes exploraciones:

# %% [markdown]
# 1. Obtener una tabla que muestre los promedios de calorías agrupados por "Beverage_category" (Es similar a crear una tabla de frecuencias, pero en lugar de contar registros se calcula el promedio: "mean")
# 1. Construir un diagrama de caja que muestre la distribución de calorías, proteínas y carbohidratos.
# 1. Construir un diagrama de caja que muestre la distribución de calorías, proteínas y carbohidratos solo para el caso donde "Beverage_category" es Smoothies.

# %%
# Sugerencia para obtener los nombres correctos de las columnas de este dataSet:
dfStarbucks = pd.read_csv('starbucks_drinkMenu_expanded.csv')
dfStarbucks.columns
# Notarán que los algunos nombres tienen espacios en blanco al inicio y final
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %% [markdown]
# #### Cargue el archivo EscuelaTech.csv en un dataFrame y realice las siguientes exploraciones:

# %% [markdown]
# 1. Construir un diagrama de caja que permita comparar la distribución de las calificaciones de matemática por género y adecuación curricular
# 1. Construir tres histogramas uno para cada distribución de calificaciones (matemática, ciencias y literatura).

# %% [markdown]
# ### Respuestas

# %% [markdown]
# ## Ejercicio #1

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv('/nhanes_2015_2016.csv')


#1
Relaciones = {1: 'Casado', 2: 'Viudas', 3: 'divorciadso', 4: 'separados', 5: 'nunca se ha casado', 6: 'en pareja normal', 77: 'Rechazado', 99: 'no se sabe '}

df['EstadoCivil'] = df['DMDMARTL'].map(Relaciones)
display(df.head())

print("------------------"),print("------------------"),print("------------------"),print("------------------")
#2
df['Genero'] = df['RIAGENDR'].map({1: 'hombre', 2: 'mujer'})
display(df['Genero'])


print("------------------"),print("------------------"),print("------------------"),print("------------------"),print("------------------"),print("------------------")
#3
dfMujer = df[df['Genero'] == 'mujer'].copy()
Edades = [0, 20, 30, 40, 50, 60, 70, 80, 90, 100]
dfMujer['Edades'] = pd.cut(dfMujer['RIDAGEYR'], bins=Edades)
display("mujres con su franja de edad: ",dfMujer)

Estado1= dfMujer.groupby(['Edades', 'EstadoCivil']).size().unstack(fill_value=0) #.size() cuenta cuantas mujeres hay en cada grupo  .unstack() lo convierte en una tabla donde el EstadoCivil son las columna
display("Mujeres y su estado ",Estado1)
print("------------------"),print("------------------"),print("------------------"),print("------------------"),print("------------------"),print("------------------")

#4
dfHombre = df[df['Genero'] == 'hombre'].copy()
Edades = [0, 20, 30, 40, 50, 60, 70, 80, 90, 100]
dfHombre['Edades'] = pd.cut(dfHombre['RIDAGEYR'], bins=Edades)
display("hombres con su franja de edad: ",dfHombre)
Estado2= dfHombre.groupby(['Edades', 'EstadoCivil']).size().unstack(fill_value=0) #.size() cuenta cuantos hombres hay en cada grupo  .unstack() lo convierte en una tabla donde el EstadoCivil son las columna
display("Hombres y su estado ",Estado2)

print("------------------"),print("------------------"),print("------------------"),print("------------------"),print("------------------"),print("------------------")

#5
import matplotlib.pyplot as plt
import seaborn as sns

#histograma hombre
plt.subplot(1, 2, 1)
sns.histplot(data=df_hombre, x='BMXHT', kde=True)
plt.title('altura en Hombres')
plt.xlabel('altura')
plt.ylabel('frecuencia')

#histograma Mujer

plt.subplot(1, 2, 2) # 1 fila, 2 columnas, segundo gráfico
sns.histplot(data=df_mujer, x='BMXHT', kde=True, color='salmon')
plt.title(' ltura en Mujeres')
plt.xlabel('altura)')
plt.ylabel('frecuencia')

print("------------------"),print("------------------"),print("------------------"),print("------------------"),print("------------------"),print("------------------")

#6
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Genero', y='BMXHT')
plt.xlabel('genero')
plt.ylabel('altura')
plt.show()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  ...  BMXARMC  BMXWAIST  HIQ210       EstadoCivil
# 0  83732     1.0     NaN     1.0  ...     35.9     101.1     2.0            Casado
# 1  83733     1.0     NaN     6.0  ...     33.2     107.9     NaN       divorciadso
# 2  83734     1.0     NaN     NaN  ...     31.0     116.5     2.0            Casado
# 3  83735     2.0     1.0     1.0  ...     38.3     110.1     2.0  en pareja normal
# 4  83736     2.0     1.0     1.0  ...     27.2      80.4     2.0       divorciadso
#
# [5 rows x 29 columns]
# ------------------
# ------------------
# ------------------
# ------------------
# 0       hombre
# 1       hombre
# 2       hombre
# 3        mujer
# 4        mujer
#          ...
# 5730     mujer
# 5731    hombre
# 5732     mujer
# 5733    hombre
# 5734     mujer
# Name: Genero, Length: 5735, dtype: object
# ------------------
# ------------------
# ------------------
# ------------------
# ------------------
# ------------------
# ...

# %% [markdown]
# ## Ejercicio 2

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler , MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
dataFrame = pd.read_csv('/content/starbucks_drinkMenu_expanded.csv')
dfStarbucks = pd.read_csv('starbucks_drinkMenu_expanded.csv')
display(dfStarbucks.columns)

#1
#nos traemos los nombres de los grupos que hayan
dfStarbucks = pd.read_csv('starbucks_drinkMenu_expanded.csv')
display(dfStarbucks.columns)
# le decimos que vaya a calorias dentro de todos los productos del grupo y le haga el promedio
calorias = dataFrame.groupby('Beverage_category')['Calories'].mean()
display(calorias)

#2
#Para esto usamos el melt de la libreria de seaborn  , lo cual lo que hace es que nos ayuda a dividir("derretir") las columnas y hacerlas en dos.
datosnuevos = dataFrame.melt(
    value_vars=['Calories', ' Protein (g) ', ' Total Carbohydrates (g) '],
    var_name='nutriente', # esto lo que hace es que crea una nueva columna de los datos derretidos que usamos arriba , en este caso con el nombre de nutrientes
    value_name='cantidad' # esto lo que hace es que crea una crea una nueva columna de los datos derretidos que usamos arriba , en este caso con el nombre de cantidad
)

plt.figure(figsize=(10, 7))
sns.boxplot(data=datosnuevos, x='nutriente', y='cantidad')

plt.show()

print("---------------------------------------------------")
#3

df2 = dataFrame[dataFrame['Beverage_category'] == 'Smoothies']
datosnuevos = df2.melt(
    value_vars=['Calories', ' Protein (g) ', ' Total Carbohydrates (g) '],
    var_name='nutriente', # esto lo que hace es que crea una nueva columna de los datos derretidos que usamos arriba , en este caso con el nombre de nutrientes
    value_name='cantidad' # esto lo que hace es que crea una crea una nueva columna de los datos derretidos que usamos arriba , en este caso con el nombre de cantidad
)
plt.figure(figsize=(5, 5))
sns.boxplot(data=datosnuevos, x='nutriente', y='cantidad')

plt.show()
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')
# Beverage_category
# Classic Espresso Drinks              140.172414
# Coffee                                 4.250000
# Frappuccino® Blended Coffee          276.944444
# ...
